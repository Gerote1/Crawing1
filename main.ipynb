# %%
import pandas as pd

# %%
df=pd.read_csv("results.csv")
df
# Out:
#                      Domain  \
# 0                 clutch.co
# 1          www.justdial.com
# 2          www.goodfirms.co
# 3            www.naukri.com
# 4          selectedfirms.co
# ..                      ...
# 499         mspalliance.com
# 500     www.crowdstrike.com
# 501         www.acronis.com
# 502          www.forbes.com
# 503  www.cloud-kinetics.com
#
#                                                  Title  \
# 0                                     Just a moment...
# 1                                        Access Denied
# 2                                     Just a moment...
# 3                                                  NaN
# 4    Best IT Services Companies in Delhi NCR | Revi...
# ..                                                 ...
# 499    MSPAlliance | Certifying MSPs for Over 20 Years
# 500  What is a Managed Service Provider (MSP)? | Cr...
# 501  What is a Managed Service Provider (MSP)? - Ac...
# 502  What Is A Managed Service Provider (MSP)? – Fo...
# ...
